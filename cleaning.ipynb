# %%
import pandas as pd

# %%
data_1 = pd.read_csv('dataset/emails.csv')
data_1.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
data_1['text'] = data_1['text'].str.replace('Subject:', '')

# %%
data_1 = data_1.rename(columns={'spam': 'label'})
data_1
# Out:
#                                                    text  label
# 0      naturally irresistible your corporate identit...      1
# 1      the stock trading gunslinger  fanny is merril...      1
# 2      unbelievable new homes made easy  im wanting ...      1
# 3      4 color printing special  request additional ...      1
# 4      do not have money , get software cds from her...      1
# ...                                                 ...    ...
# 5723   re : research and development charges to gpg ...      0
# 5724   re : receipts from visit  jim ,  thanks again...      0
# 5725   re : enron case study update  wow ! all on th...      0
# 5726   re : interest  david ,  please , call shirley...      0
# 5727   news : aurora 5 . 2 update  aurora version 5 ...      0
#
# [5728 rows x 2 columns]

# %%
data_1 = data_1.replace([1, 0], ['spam', 'not spam'])
data_1
# Out:
#                                                    text     label
# 0      naturally irresistible your corporate identit...      spam
# 1      the stock trading gunslinger  fanny is merril...      spam
# 2      unbelievable new homes made easy  im wanting ...      spam
# 3      4 color printing special  request additional ...      spam
# 4      do not have money , get software cds from her...      spam
# ...                                                 ...       ...
# 5723   re : research and development charges to gpg ...  not spam
# 5724   re : receipts from visit  jim ,  thanks again...  not spam
# 5725   re : enron case study update  wow ! all on th...  not spam
# 5726   re : interest  david ,  please , call shirley...  not spam
# 5727   news : aurora 5 . 2 update  aurora version 5 ...  not spam
#
# [5728 rows x 2 columns]

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5728 entries, 0 to 5727
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5728 non-null   object
#  1   label   5728 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 89.6+ KB

# %%
data_2 = pd.read_csv('dataset\spam_or_not_spam.csv')
data_2.head()
# Out:
#                                                email  label
# 0   date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...      0
# 1  martin a posted tassos papadopoulos the greek ...      0
# 2  man threatens explosion in moscow thursday aug...      0
# 3  klez the virus that won t die already the most...      0
# 4   in adding cream to spaghetti carbonara which ...      0

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2999 entries, 0 to 2999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2999 non-null   object
#  1   label   2999 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 70.3+ KB

# %%
data_2 = data_2.dropna(subset=['email'])

# %%
data_2 = data_2.rename(columns={'email': 'text'})

# %%
data_2 = data_2.replace([0, 1], ['not spam', 'spam'])

# %%
data_2.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
data_3 = pd.read_csv('dataset/spam.csv')
data_3.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
data_3 = data_3.rename(columns={'Message': 'text', 'Category': 'label'})
data_3 = data_3.replace(['ham'], ['not spam'])
data_3 = data_3[['text', 'label']]
data_3
# Out:
#                                                    text     label
# 0     Go until jurong point, crazy.. Available only ...  not spam
# 1                         Ok lar... Joking wif u oni...  not spam
# 2     Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     U dun say so early hor... U c already then say...  not spam
# 4     Nah I don't think he goes to usf, he lives aro...  not spam
# ...                                                 ...       ...
# 5567  This is the 2nd time we have tried 2 contact u...      spam
# 5568               Will ü b going to esplanade fr home?  not spam
# 5569  Pity, * was in mood for that. So...any other s...  not spam
# 5570  The guy did some bitching but I acted like i'd...  not spam
# 5571                         Rofl. Its true to its name  not spam
#
# [5572 rows x 2 columns]

# %%
data_1
# Out:
#                                                    text     label
# 0      naturally irresistible your corporate identit...      spam
# 1      the stock trading gunslinger  fanny is merril...      spam
# 2      unbelievable new homes made easy  im wanting ...      spam
# 3      4 color printing special  request additional ...      spam
# 4      do not have money , get software cds from her...      spam
# ...                                                 ...       ...
# 5723   re : research and development charges to gpg ...  not spam
# 5724   re : receipts from visit  jim ,  thanks again...  not spam
# 5725   re : enron case study update  wow ! all on th...  not spam
# 5726   re : interest  david ,  please , call shirley...  not spam
# 5727   news : aurora 5 . 2 update  aurora version 5 ...  not spam
#
# [5728 rows x 2 columns]

# %%
data_2
# Out:
#                                                    text     label
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...  not spam
# 1     martin a posted tassos papadopoulos the greek ...  not spam
# 2     man threatens explosion in moscow thursday aug...  not spam
# 3     klez the virus that won t die already the most...  not spam
# 4      in adding cream to spaghetti carbonara which ...  not spam
# ...                                                 ...       ...
# 2995   abc s good morning america ranks it the NUMBE...      spam
# 2996   hyperlink hyperlink hyperlink let mortgage le...      spam
# 2997   thank you for shopping with us gifts for all ...      spam
# 2998   the famous ebay marketing e course learn to s...      spam
# 2999   hello this is chinese traditional 子 件 NUMBER世...      spam
#
# [2999 rows x 2 columns]

# %%
data_3
# Out:
#                                                    text     label
# 0     Go until jurong point, crazy.. Available only ...  not spam
# 1                         Ok lar... Joking wif u oni...  not spam
# 2     Free entry in 2 a wkly comp to win FA Cup fina...      spam
# 3     U dun say so early hor... U c already then say...  not spam
# 4     Nah I don't think he goes to usf, he lives aro...  not spam
# ...                                                 ...       ...
# 5567  This is the 2nd time we have tried 2 contact u...      spam
# 5568               Will ü b going to esplanade fr home?  not spam
# 5569  Pity, * was in mood for that. So...any other s...  not spam
# 5570  The guy did some bitching but I acted like i'd...  not spam
# 5571                         Rofl. Its true to its name  not spam
#
# [5572 rows x 2 columns]

# %%
data = pd.concat([data_1, data_2, data_3], ignore_index=True)
data
# Out:
#                                                     text     label
# 0       naturally irresistible your corporate identit...      spam
# 1       the stock trading gunslinger  fanny is merril...      spam
# 2       unbelievable new homes made easy  im wanting ...      spam
# 3       4 color printing special  request additional ...      spam
# 4       do not have money , get software cds from her...      spam
# ...                                                  ...       ...
# 14294  This is the 2nd time we have tried 2 contact u...      spam
# 14295               Will ü b going to esplanade fr home?  not spam
# 14296  Pity, * was in mood for that. So...any other s...  not spam
# 14297  The guy did some bitching but I acted like i'd...  not spam
# 14298                         Rofl. Its true to its name  not spam
#
# [14299 rows x 2 columns]

# %%
data.label.unique()
# Out:
# array(['spam', 'not spam'], dtype=object)

# %%
data.to_csv('dataset\cleaned_dataset.csv', index=False)
print('Your dataset has been cleaned, merged, and saved.')
# Out:
# ---------------------------------------------------------------------------
# IllegalCharacterError                     Traceback (most recent call last)
# Cell In[26], line 2
#       1 data.to_csv('dataset\cleaned_dataset.csv', index=False)
# ----> 2 data.to_excel('dataset\cleaned_dataset.xlsx', index=False)
#       3 print('Your dataset has been cleaned, merged, and saved.')
#
# File d:\Aplikasi\Program\python\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353     engine_kwargs=engine_kwargs,
#    2354 )
#
# File d:\Aplikasi\Program\python\lib\site-packages\pandas\io\formats\excel.py:955, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     952     need_save = True
#     954 try:
# --> 955     writer._write_cells(
#     956         formatted_cells,
#     957         sheet_name,
#     958         startrow=startrow,
#     959         startcol=startcol,
#     960         freeze_panes=freeze_panes,
#     961     )
#     962 finally:
#     963     # make sure to close opened file handles
#     964     if need_save:
#
# File d:\Aplikasi\Program\python\lib\site-packages\pandas\io\excel\_openpyxl.py:490, in OpenpyxlWriter._write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     486 for cell in cells:
#     487     xcell = wks.cell(
#     488         row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     489     )
# --> 490     xcell.value, fmt = self._value_with_fmt(cell.val)
#     491     if fmt:
#     492         xcell.number_format = fmt
#
# File d:\Aplikasi\Program\python\lib\site-packages\openpyxl\cell\cell.py:218, in Cell.value(self, value)
#     215 @value.setter
#     216 def value(self, value):
#     217     """Set the value and infer type and display options."""
# --> 218     self._bind_value(value)
#
# File d:\Aplikasi\Program\python\lib\site-packages\openpyxl\cell\cell.py:197, in Cell._bind_value(self, value)
#     194         self.number_format = get_time_format(t)
#     196 elif dt == "s" and not isinstance(value, CellRichText):
# --> 197     value = self.check_string(value)
#     198     if len(value) > 1 and value.startswith("="):
#     199         self.data_type = 'f'
#
# File d:\Aplikasi\Program\python\lib\site-packages\openpyxl\cell\cell.py:165, in Cell.check_string(self, value)
#     163 value = value[:32767]
#     164 if next(ILLEGAL_CHARACTERS_RE.finditer(value), None):
# --> 165     raise IllegalCharacterError(f"{value} cannot be used in worksheets.")
#     166 return value
#
# IllegalCharacterError:  life - time upgrades for freeq 4 ili 6 p 8  below is the result of your feedback form . it was submitted by  ( blowdamovie @ atlas . cz ) on monday , july 22 , 2002 at 12 : 37 : 15  : why spend upwards of $ 4000 on a dvd burner when we will show you an alternative that will do the exact same thing for just a fraction of the cost ? copy your dvd ' s now . best price on the net . click here : http : / / 010 @ www . dvdcopyxp . com / cgi - bin / enter . cgi ? marketing _ id?xo 07 click to remove http : / / 011 @ www . spambites . com / cgi - bin / enter . cgi ? spambytes _ id  0115  cannot be used in worksheets.
